# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py
import plotly.express as px
import dtale
#dont show warning 
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install dtale
# Out:
# ...
#   Using cached dtale-3.17.0-py2.py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached dash_daq-0.5.0-py3-none-any.whl
# ...
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# ...
#   Using cached squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# ...
#   Using cached strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached dash_bootstrap_components-1.7.1-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# ...

# %% [markdown]
# # **EDA WITH DTALE**

# %%
#Loading data set
df=pd.read_csv(r'C:\Users\PC\OneDrive\Desktop\Data\titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.columns = [col.strip() for col in df.columns]
df.replace(['male','female'],['Male','Female'],inplace=True)
#Making first letter of every word capital
df.columns = [col.capitalize() for col in df.columns]
df=df[['Survived','Pclass','Sex','Age','Parch','Fare','Embarked','Class','Who','Deck','Alive','Alone']]
df
# Out:
#      Survived  Pclass     Sex   Age  Parch     Fare Embarked  Class    Who  \
# 1           1       1  Female  38.0      0  71.2833        C  First  woman
# 3           1       1  Female  35.0      0  53.1000        S  First  woman
# 6           0       1    Male  54.0      0  51.8625        S  First    man
# 10          1       3  Female   4.0      1  16.7000        S  Third  child
# 11          1       1  Female  58.0      0  26.5500        S  First  woman
# ..        ...     ...     ...   ...    ...      ...      ...    ...    ...
# 871         1       1  Female  47.0      1  52.5542        S  First  woman
# 872         0       1    Male  33.0      0   5.0000        S  First    man
# 879         1       1  Female  56.0      1  83.1583        C  First  woman
# 887         1       1  Female  19.0      0  30.0000        S  First  woman
# 889         1       1    Male  26.0      0  30.0000        C  First    man
#
#     Deck Alive  Alone
# 1      C   yes  False
# ...

# %%
d=dtale.show(df)

# %%
d.open_browser()

# %%
#closing dtale

d.kill()
# Out:
# 2025-05-24 20:07:53,695 - INFO     - Executing shutdown...
# 2025-05-24 20:07:53,696 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
